# %%
frase = "Curso de Python"
print("Num caracs", len(frase))
# Out:
# Num caracs 15

# %%
#----

frase = "Curso de Python"
linguagem = frase[9:len(frase)]
print(linguagem)
print("Primeira Letra:", frase[0])
# Out:
# Python
# Primeira Letra: C

# %%
#----

frase = "Esse é o curso de IA Generativa. Você pode criar programas com prompts."
mudanca = frase.replace("prompts", "Python")
print(frase)
print(mudanca)
# Out:
# Esse é o curso de IA Generativa. Você pode criar programas com prompts.
# Esse é o curso de IA Generativa. Você pode criar programas com Python.

# %%
#----

frase = "Olá mundo teste isso vai ficar teste final"
inicio = frase.find("teste") + len("teste")
fim = frase.find("teste", inicio)
print(frase[inicio:fim])
# Out:
#  isso vai ficar

# %%
#----

frase = "Esse é o curso de IA Generativa. Você pode criar programas com prompts."
somente_prim = frase.replace("prompts", "Python", 1)
print(somente_prim)
# Out:
# Esse é o curso de IA Generativa. Você pode criar programas com Python.

# %%
#----

nome_curso = "Python"
ola = "Bom dia."
frase = ola + " Esse é o curso de " + nome_curso + "."
print(frase)
# Out:
# Bom dia. Esse é o curso de Python.

# %%
#----

frase = "Esse é um texto\nde\texemplo"
print(frase)
# Out:
# Esse é um texto
# de	exemplo

# %%
#----

frase1 = "CURSO de Python"
print(frase1.upper())
print(frase1.lower())
print(frase1.capitalize())
# Out:
# CURSO DE PYTHON
# curso de python
# Curso de python

# %%
#----

frase = "Esse é o curso de Python - Foco em iniciantes"
lista1 = frase.split(" ")
for item in lista1:
    print(item)
lista2 = frase.split("-")
for item in lista2:
    print(item)
# Out:
# Esse
# é
# o
# curso
# de
# Python
# -
# Foco
# em
# iniciantes
# Esse é o curso de Python
#  Foco em iniciantes

# %%
#----

frase = "Olá mundo teste isso vai ficar teste final"
inicio = frase.find("teste") + len("teste")
fim = frase.find("teste", inicio)
print(frase[inicio:fim])
# Out:
#  isso vai ficar

# %%
#----

anterior = 5000
atual = 5500
diferenca = atual - anterior
pct = diferenca/anterior * 100
frase = "A diferença de salário é de R${}, ou seja, {}%"
formatado = frase.format(diferenca, pct)
print(formatado)
# Out:
# A diferença de salário é de R$500, ou seja, 10.0%

# %%
salario = 7500
print("O seu salário é {}.".format(salario))
# Out:
# O seu salário é 7500.

# %%
salario = 7500
print("O seu salário é {:f}.".format(salario))
# Out:
# O seu salário é 7500.000000.

# %%
salario = 7500
print("O seu salário é {:.2f}.".format(salario))
# Out:
# O seu salário é 7500.00.

# %%
salario = 7500
print("O seu salário é {:.2f}.".format(salario))
# Out:
# O seu salário é 7500.00.
